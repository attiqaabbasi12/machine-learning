# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("price.csv")
df.head().style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_f0694_row0_col0, #T_f0694_row0_col9, #T_f0694_row2_col3, #T_f0694_row3_col1, #T_f0694_row3_col3, #T_f0694_row3_col4, #T_f0694_row3_col5, #T_f0694_row4_col2, #T_f0694_row4_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f0694_row0_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_f0694_row0_col2, #T_f0694_row0_col3, #T_f0694_row0_col4, #T_f0694_row1_col2, #T_f0694_row1_col3, #T_f0694_row1_col4, #T_f0694_row2_col4, #T_f0694_row4_col0, #T_f0694_row4_col1, #T_f0694_row4_col3, #T_f0694_row4_col5, #T_f0694_row4_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f0694_row0_col5 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_f0694_row1_col0, #T_f0694_row2_col2 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_f0694_row1_col1 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_f0694_row1_col5 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_f0694_row1_col9 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_f0694_row2_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_f0694_row2_col1 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_f0694_row2_col5 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_f0694_row2_col9 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_f0694_row3_col0, #T_f0694_row3_col2 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_f0694_row3_col9 {
#   background-color: #dddbec;
#   color: #000000;
# }
# </style>
# <table id="T_f0694">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0694_level0_col0" class="col_heading level0 col0" >Id</th>
#       <th id="T_f0694_level0_col1" class="col_heading level0 col1" >Area</th>
#       <th id="T_f0694_level0_col2" class="col_heading level0 col2" >Bedrooms</th>
#       <th id="T_f0694_level0_col3" class="col_heading level0 col3" >Bathrooms</th>
#       <th id="T_f0694_level0_col4" class="col_heading level0 col4" >Floors</th>
#       <th id="T_f0694_level0_col5" class="col_heading level0 col5" >YearBuilt</th>
#       <th id="T_f0694_level0_col6" class="col_heading level0 col6" >Location</th>
#       <th id="T_f0694_level0_col7" class="col_heading level0 col7" >Condition</th>
#       <th id="T_f0694_level0_col8" class="col_heading level0 col8" >Garage</th>
#       <th id="T_f0694_level0_col9" class="col_heading level0 col9" >Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0694_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0694_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_f0694_row0_col1" class="data row0 col1" >1360</td>
#       <td id="T_f0694_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_f0694_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_f0694_row0_col4" class="data row0 col4" >3</td>
#       <td id="T_f0694_row0_col5" class="data row0 col5" >1970</td>
#       <td id="T_f0694_row0_col6" class="data row0 col6" >Downtown</td>
#       <td id="T_f0694_row0_col7" class="data row0 col7" >Excellent</td>
#       <td id="T_f0694_row0_col8" class="data row0 col8" >No</td>
#       <td id="T_f0694_row0_col9" class="data row0 col9" >149919</td>
#     </tr>
#     <tr>
#       <th id="T_f0694_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f0694_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_f0694_row1_col1" class="data row1 col1" >4272</td>
#       <td id="T_f0694_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_f0694_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_f0694_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_f0694_row1_col5" class="data row1 col5" >1958</td>
#       <td id="T_f0694_row1_col6" class="data row1 col6" >Downtown</td>
#       <td id="T_f0694_row1_col7" class="data row1 col7" >Excellent</td>
#       <td id="T_f0694_row1_col8" class="data row1 col8" >No</td>
#       <td id="T_f0694_row1_col9" class="data row1 col9" >424998</td>
#     </tr>
#     <tr>
#       <th id="T_f0694_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f0694_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_f0694_row2_col1" class="data row2 col1" >3592</td>
#       <td id="T_f0694_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_f0694_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_f0694_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_f0694_row2_col5" class="data row2 col5" >1938</td>
#       <td id="T_f0694_row2_col6" class="data row2 col6" >Downtown</td>
#       <td id="T_f0694_row2_col7" class="data row2 col7" >Good</td>
#       <td id="T_f0694_row2_col8" class="data row2 col8" >No</td>
#       <td id="T_f0694_row2_col9" class="data row2 col9" >266746</td>
#     </tr>
#     <tr>
#       <th id="T_f0694_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f0694_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_f0694_row3_col1" class="data row3 col1" >966</td>
#       <td id="T_f0694_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_f0694_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_f0694_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_f0694_row3_col5" class="data row3 col5" >1902</td>
#       <td id="T_f0694_row3_col6" class="data row3 col6" >Suburban</td>
#       <td id="T_f0694_row3_col7" class="data row3 col7" >Fair</td>
#       <td id="T_f0694_row3_col8" class="data row3 col8" >Yes</td>
#       <td id="T_f0694_row3_col9" class="data row3 col9" >244020</td>
#     </tr>
#     <tr>
#       <th id="T_f0694_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f0694_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_f0694_row4_col1" class="data row4 col1" >4926</td>
#       <td id="T_f0694_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_f0694_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_f0694_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_f0694_row4_col5" class="data row4 col5" >1975</td>
#       <td id="T_f0694_row4_col6" class="data row4 col6" >Downtown</td>
#       <td id="T_f0694_row4_col7" class="data row4 col7" >Fair</td>
#       <td id="T_f0694_row4_col8" class="data row4 col8" >Yes</td>
#       <td id="T_f0694_row4_col9" class="data row4 col9" >636056</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
df.columns
# Out:
# Index(['Id', 'Area', 'Bedrooms', 'Bathrooms', 'Floors', 'YearBuilt',
#        'Location', 'Condition', 'Garage', 'Price'],
#       dtype='object')

# %%
df.shape
# Out:
# (2000, 10)

# %%
df.isnull().sum()
# Out:
# Id           0
# Area         0
# Bedrooms     0
# Bathrooms    0
# Floors       0
# YearBuilt    0
# Location     0
# Condition    0
# Garage       0
# Price        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         2000 non-null   int64
#  1   Area       2000 non-null   int64
#  2   Bedrooms   2000 non-null   int64
#  3   Bathrooms  2000 non-null   int64
#  4   Floors     2000 non-null   int64
#  5   YearBuilt  2000 non-null   int64
#  6   Location   2000 non-null   object
#  7   Condition  2000 non-null   object
#  8   Garage     2000 non-null   object
#  9   Price      2000 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 156.4+ KB

# %%
df.describe()
# Out:
#                 Id         Area     Bedrooms   Bathrooms       Floors  \
# count  2000.000000  2000.000000  2000.000000  2000.00000  2000.000000
# mean   1000.500000  2786.209500     3.003500     2.55250     1.993500
# std     577.494589  1295.146799     1.424606     1.10899     0.809188
# min       1.000000   501.000000     1.000000     1.00000     1.000000
# 25%     500.750000  1653.000000     2.000000     2.00000     1.000000
# 50%    1000.500000  2833.000000     3.000000     3.00000     2.000000
# 75%    1500.250000  3887.500000     4.000000     4.00000     3.000000
# max    2000.000000  4999.000000     5.000000     4.00000     3.000000
#
#          YearBuilt          Price
# count  2000.000000    2000.000000
# mean   1961.446000  537676.855000
# std      35.926695  276428.845719
# min    1900.000000   50005.000000
# 25%    1930.000000  300098.000000
# 50%    1961.000000  539254.000000
# 75%    1993.000000  780086.000000
# max    2023.000000  999656.000000

# %%
numerical_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']
print(f'Numerical features: {len(numerical_features)}')
print(f'Categorical features: {len(categorical_features)}')
# Out:
# Numerical features: 7
# Categorical features: 3

# %%
numerical_features.remove("Id")

# %%
for feature in numerical_features:
    plt.figure(figsize=(8,4))
    plt.subplot(1,2,1)
    sns.histplot(df[feature], bins = 30, kde=True, color='red') 
    plt.title(f"Histogram of {feature}")

    plt.subplot(1,2,2)
    sns.boxplot(x=df[feature], color='red')
    plt.title(f"Boxplot of {feature}")
    plt.tight_layout()
    plt.show()

# %%
for feature in categorical_features:
    count = df[feature].value_counts()
    plt.figure(figsize=(8,4))
    plt.subplot(1,2,1)
    sns.countplot(x=df[feature], palette='Set2')
    plt.title(f"Countplot of {feature}")

    plt.subplot(1,2,2)
    plt.pie(count, labels=count.index, autopct='%1.1f%%', startangle=90)
    plt.title(f"Pie chart of {feature}")
    plt.tight_layout()
    plt.show()
